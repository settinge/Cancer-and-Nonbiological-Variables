# %%
import pandas as pd
import numpy as np
from config import api_key
import requests

# %%
income_df = pd.read_csv("ACSCP5Y2018.CP03_data_with_overlays_2020-01-29T205006.csv")
income_df
# Out:
#       GEO_ID                  NAME  \
# 0         id  Geographic Area Name
# 1  0100000US         United States
#
#                                  CP03_2014_2018_004E  \
# 0  2014-2018 Estimate!!EMPLOYMENT STATUS!!Populat...
# 1                                               59.3
#
#                                  CP03_2009_2013_004E  \
# 0  2009-2013 Estimate!!EMPLOYMENT STATUS!!Populat...
# 1                                               57.6
#
#                                           CP03_004SS  \
# 0  Statistical Significance!!EMPLOYMENT STATUS!!P...
# 1                                                  *
#
#                                  CP03_2014_2018_005E  \
# 0  2014-2018 Estimate!!EMPLOYMENT STATUS!!Populat...
# 1                                                3.7
#
#                                  CP03_2009_2013_005E  \
# 0  2009-2013 Estimate!!EMPLOYMENT STATUS!!Populat...
# 1                                                6.2
#
# ...

# %%
income_df.loc("INCOME")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-226a9a67e75a> in <module>
# ----> 1 income_df.loc("INCOME")
#
# ~\New_Anaconda\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     110
#     111         if axis is not None:
# --> 112             axis = self.obj._get_axis_number(axis)
#     113         new_self.axis = axis
#     114         return new_self
#
# ~\New_Anaconda\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     409             except KeyError:
#     410                 pass
# --> 411         raise ValueError("No axis named {0} for object type {1}".format(axis, cls))
#     412
#     413     @classmethod
#
# ValueError: No axis named INCOME for object type <class 'pandas.core.frame.DataFrame'>
