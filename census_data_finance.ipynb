# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# !pip install gmaps
# !pip install census
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# ...
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
#Importing dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
from census import Census
from us import states

#census key
from config import g_key

#census API Key
from config import acs_key
c = Census(acs_key, year=2018)

# %%
census_data = c.acs5.get(("B01003_001E", "B17001_002E"), {
    'for': 'zip code tabulation area:*'})

#convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                    "B17001_002E": "Poverty Count",
                                    "zip code tabulation area": "Zipcode"})
#Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = census_pd["Poverty Count"]
/ census_pd["Population"]
census_pd
# Final DataFrame
del census_pd["Poverty Count"]
census_pd
# Out:
#        Population Zipcode  Poverty Rate
# 0         17242.0   00601       10772.0
# 1         38442.0   00602       19611.0
# 2         48814.0   00603       24337.0
# 3          6437.0   00606        4163.0
# 4         27073.0   00610       11724.0
# ...           ...     ...           ...
# 33115        15.0   99923           0.0
# 33116       927.0   99925         172.0
# 33117      1635.0   99926         235.0
# 33118        38.0   99927          28.0
# 33119      2484.0   99929         192.0
#
# [33120 rows x 3 columns]

# %%
census_data = c.acs5.get(("B01003_001E", "B19001_001E"), {
    'for': 'zip code tabulation area:*'})

census_pd = pd.DataFrame(census_data)

census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                         "B19001_001E": "Household Income",
                         "zip code tabulation area" : "zipcode"
                         })
census_pd
# Out:
#        Population  Household Income zipcode
# 0         17242.0            5517.0   00601
# 1         38442.0           12738.0   00602
# 2         48814.0           19233.0   00603
# 3          6437.0            2014.0   00606
# 4         27073.0            8858.0   00610
# ...           ...               ...     ...
# 33115        15.0              15.0   99923
# 33116       927.0             325.0   99925
# 33117      1635.0             480.0   99926
# 33118        38.0              29.0   99927
# 33119      2484.0            1074.0   99929
#
# [33120 rows x 3 columns]

# %%
d = Census(acs_key, year=2017)

census_pd = d.acs5.get(("B01003_001E", "B19001_001E"), {
    'for': 'zip code tabulation area:*'})

census_pd = pd.DataFrame(census_data)

census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                         "B19001_001E": "Household Income",
                         "zip code tabulation area" : "zipcode"
                         })
census_pd
# Out:
#        Population  Household Income zipcode
# 0         17242.0            5517.0   00601
# 1         38442.0           12738.0   00602
# 2         48814.0           19233.0   00603
# 3          6437.0            2014.0   00606
# 4         27073.0            8858.0   00610
# ...           ...               ...     ...
# 33115        15.0              15.0   99923
# 33116       927.0             325.0   99925
# 33117      1635.0             480.0   99926
# 33118        38.0              29.0   99927
# 33119      2484.0            1074.0   99929
#
# [33120 rows x 3 columns]

# %%
e = Census(acs_key, year = 2016)

census_pd = e.acs5.get(("B01003_001E", "B19001_001E"), {
    'for': 'zip code tabulation area:*'})
census_pd = pd.DataFrame(census_data)

census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                         "B19001_001E": "Household Income",
                         "zip code tabulation area" : "zipcode"
                         })
census_pd
# Out:
#        Population  Household Income zipcode
# 0         17242.0            5517.0   00601
# 1         38442.0           12738.0   00602
# 2         48814.0           19233.0   00603
# 3          6437.0            2014.0   00606
# 4         27073.0            8858.0   00610
# ...           ...               ...     ...
# 33115        15.0              15.0   99923
# 33116       927.0             325.0   99925
# 33117      1635.0             480.0   99926
# 33118        38.0              29.0   99927
# 33119      2484.0            1074.0   99929
#
# [33120 rows x 3 columns]

# %%
f = Census(acs_key, year=2015)

census_pd = e.acs5.get(("B01003_001E", "B19001_001E"), {
    'for': 'zip code tabulation area:*'})
census_pd = pd.DataFrame(census_data)

census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                         "B19001_001E": "Household Income",
                         "zip code tabulation area" : "zipcode"
                         })
census_pd
# Out:
#        Population  Household Income zipcode
# 0         17242.0            5517.0   00601
# 1         38442.0           12738.0   00602
# 2         48814.0           19233.0   00603
# 3          6437.0            2014.0   00606
# 4         27073.0            8858.0   00610
# ...           ...               ...     ...
# 33115        15.0              15.0   99923
# 33116       927.0             325.0   99925
# 33117      1635.0             480.0   99926
# 33118        38.0              29.0   99927
# 33119      2484.0            1074.0   99929
#
# [33120 rows x 3 columns]
