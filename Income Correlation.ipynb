# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from scipy.optimize import curve_fit

# %%
income_df =pd.read_csv("State income.csv")
income_df
# Out:
#     Unnamed: 0  Population  Household Income                 State
# 0            0  20612439.0           50860.0               Florida
# 1            1  10310371.0           53559.0               Georgia
# 2            2   1428557.0           74511.0                Hawaii
# 3            3   1683140.0           51807.0                 Idaho
# 4            4  12801539.0           60960.0              Illinois
# 5            5   6633053.0           52314.0               Indiana
# 6            6   3134693.0           56247.0                  Iowa
# 7            7   2907289.0           54935.0                Kansas
# 8            8   4436974.0           46659.0              Kentucky
# 9            9   4681666.0           45146.0             Louisiana
# 10          10   1331479.0           53079.0                 Maine
# 11          11   6016447.0           78945.0              Maryland
# 12          12   6811779.0           75297.0         Massachusetts
# 13          13   9928300.0           52492.0              Michigan
# 14          14   5519952.0           65599.0             Minnesota
# 15          15   2988726.0           41754.0           Mississippi
# 16          16   6093000.0           51746.0              Missouri
# 17          17   1042520.0           50027.0               Montana
# 18          18   1907116.0           56927.0              Nebraska
# 19          19   2940058.0           55180.0                Nevada
# 20          20   1334795.0           70936.0         New Hampshire
# 21          21   8944469.0           76126.0            New Jersey
# 22          22   2081015.0           46748.0            New Mexico
# 23          23  19745289.0           62909.0              New York
# 24          24  10146788.0           50584.0        North Carolina
# 25          25    757953.0           60656.0          North Dakota
# 26          26  11614373.0           52334.0                  Ohio
# 27          27   3923561.0           49176.0              Oklahoma
# 28          28   4093465.0           57532.0                Oregon
# 29          29  12784227.0           56907.0          Pennsylvania
# 30          30   1056426.0           60596.0          Rhode Island
# 31          31   4961119.0           49501.0        South Carolina
# 32          32    865454.0           54467.0          South Dakota
# 33          33   6651194.0           48547.0             Tennessee
# 34          34  27862596.0           56565.0                 Texas
# 35          35   3051217.0           65977.0                  Utah
# 36          36    624594.0           57677.0               Vermont
# 37          37   8411808.0           68114.0              Virginia
# 38          38   7288000.0           67106.0            Washington
# 39          39   1831102.0           43385.0         West Virginia
# 40          40   5778709.0           56811.0             Wisconsin
# 41          41    585501.0           59882.0               Wyoming
# 42          42   3411307.0           20078.0           Puerto Rico
# 43          43   4863300.0           46257.0               Alabama
# 44          44    741894.0           76440.0                Alaska
# 45          45   6931071.0           53558.0               Arizona
# 46          46   2988248.0           44334.0              Arkansas
# 47          47  39250017.0           67739.0            California
# 48          48   5540545.0           65685.0              Colorado
# 49          49   3576452.0           73433.0           Connecticut
# 50          50    952065.0           61757.0              Delaware
# 51          51    681170.0           75506.0  District of Columbia

# %%
cancer_df = pd.read_csv("Resource/Added_final_combined_cancer_data.csv")
cancer_df
# Out:
#                    State  Incidence Rate  Average Annual Count_x  Death Rate  \
# 0               Kentucky           521.0                 26945.0       198.0
# 1               Delaware           498.0                  5803.0       170.0
# 2           Pennsylvania           487.0                 79060.0       169.0
# 3          New Hampshire           484.0                  8129.0       162.0
# 4             New Jersey           483.0                 50921.0       154.0
# 5               New York           483.0                111527.0       151.0
# 6              Louisiana           481.0                 24888.0       183.0
# 7           Rhode Island           478.0                  6163.0       165.0
# 8          West Virginia           476.0                 11653.0       189.0
# 9                  Maine           476.0                  8700.0       174.0
# 10                  Iowa           475.0                 17806.0       166.0
# 11           Connecticut           472.0                 20843.0       146.0
# 12           Mississippi           469.0                 15923.0       194.0
# 13              Arkansas           468.0                 16551.0       185.0
# 14             Wisconsin           467.0                 32160.0       163.0
# 15               Georgia           466.0                 49003.0       166.0
# 16              Illinois           466.0                 67683.0       168.0
# 17        North Carolina           466.0                 53636.0       167.0
# 18                Kansas           464.0                 15171.0       164.0
# 19             Minnesota           464.0                 28996.0       153.0
# 20             Tennessee           463.0                 35692.0       184.0
# 21                  Ohio           462.0                 64858.0       177.0
# 22        South Carolina           457.0                 26730.0       172.0
# 23               Indiana           457.0                 34242.0       178.0
# 24          South Dakota           456.0                  4514.0       160.0
# 25              Missouri           455.0                 32947.0       176.0
# 26               Montana           454.0                  5901.0       155.0
# 27          North Dakota           454.0                  3725.0       150.0
# 28              Oklahoma           453.0                 19837.0       184.0
# 29               Vermont           453.0                  3678.0       165.0
# 30               Alabama           452.0                 26110.0       179.0
# 31               Florida           452.0                121916.0       153.0
# 32              Nebraska           452.0                  9630.0       159.0
# 33            Washington           451.0                 35813.0       157.0
# 34              Maryland           450.0                 30444.0       160.0
# 35              Michigan           450.0                 54047.0       170.0
# 36         Massachusetts           450.0                 36149.0       156.0
# 37                 Idaho           440.0                  7924.0       155.0
# 38  District of Columbia           433.0                  2818.0       169.0
# 39                Oregon           430.0                 20790.0       163.0
# 40              Virginia           419.0                 39078.0       161.0
# 41                Alaska           413.0                  2784.0       165.0
# 42                 Texas           408.0                107094.0       154.0
# 43            California           405.0                165242.0       145.0
# 44                  Utah           403.0                 10143.0       127.0
# 45              Colorado           401.0                 22701.0       139.0
# 46               Wyoming           397.0                  2638.0       145.0
# 47                Nevada           393.0                 12409.0       162.0
# 48               Arizona           387.0                 30448.0       144.0
# 49            New Mexico           374.0                  9116.0       144.0
#
#     Average Annual Count_y  Cancer Death_per_hundred_cancer_patient
# 0                  10206.0                                     38.0
# 1                   1989.0                                     34.0
# 2                  28658.0                                     36.0
# 3                   2718.0                                     33.0
# 4                  16407.0                                     32.0
# 5                  35491.0                                     32.0
# 6                   9346.0                                     38.0
# 7                   2223.0                                     36.0
# 8                   4756.0                                     41.0
# 9                   3267.0                                     38.0
# 10                  6479.0                                     36.0
# 11                  6657.0                                     32.0
# 12                  6522.0                                     41.0
# 13                  6623.0                                     40.0
# 14                 11398.0                                     35.0
# 15                 16650.0                                     34.0
# 16                 24531.0                                     36.0
# 17                 19036.0                                     35.0
# 18                  5497.0                                     36.0
# 19                  9691.0                                     33.0
# 20                 14111.0                                     40.0
# 21                 25317.0                                     39.0
# 22                  9942.0                                     37.0
# 23                 13416.0                                     39.0
# 24                  1648.0                                     37.0
# 25                 12920.0                                     39.0
# 26                  2036.0                                     35.0
# 27                  1283.0                                     34.0
# 28                  8082.0                                     41.0
# 29                  1355.0                                     37.0
# 30                 10332.0                                     40.0
# 31                 43285.0                                     36.0
# 32                  3478.0                                     36.0
# 33                 12273.0                                     34.0
# 34                 10674.0                                     35.0
# 35                 20727.0                                     38.0
# 36                 12795.0                                     35.0
# 37                  2761.0                                     35.0
# 38                  1082.0                                     38.0
# 39                  7933.0                                     38.0
# 40                 14686.0                                     38.0
# 41                   977.0                                     35.0
# 42                 38943.0                                     36.0
# 43                 58588.0                                     35.0
# 44                  3021.0                                     30.0
# 45                  7520.0                                     33.0
# 46                   943.0                                     36.0
# 47                  4934.0                                     40.0
# 48                 11508.0                                     38.0
# 49                  3514.0                                     39.0

# %%
merged_table =pd.merge(income_df, cancer_df, how="left", on="State").dropna()
#merged_table = del(merged_table["Unnamed:0"])
merged_table.head()
# Out:
#    Unnamed: 0  Population  Household Income     State  Incidence Rate  \
# 0           0  20612439.0           50860.0   Florida           452.0
# 1           1  10310371.0           53559.0   Georgia           466.0
# 3           3   1683140.0           51807.0     Idaho           440.0
# 4           4  12801539.0           60960.0  Illinois           466.0
# 5           5   6633053.0           52314.0   Indiana           457.0
#
#    Average Annual Count_x  Death Rate  Average Annual Count_y  \
# 0                121916.0       153.0                 43285.0
# 1                 49003.0       166.0                 16650.0
# 3                  7924.0       155.0                  2761.0
# 4                 67683.0       168.0                 24531.0
# 5                 34242.0       178.0                 13416.0
#
#    Cancer Death_per_hundred_cancer_patient
# 0                                     36.0
# 1                                     34.0
# 3                                     35.0
# 4                                     36.0
# 5                                     39.0

# %%
income = merged_table["Household Income"]
incidence_rate = merged_table["Incidence Rate"]

plt.scatter(income,incidence_rate, edgecolors= "black", facecolors="blue", alpha=.5)
plt.xlabel("Household Income (2018 inflated dollars)")
plt.ylabel("Incidence Rate")
plt.title("Household Income vs Cancer Incidence Rate")

(slope, intercept, rvalue, pvalue, stderr) = linregress(income, incidence_rate)
tempregress_values = income*slope + intercept
templine_eq = "y = " + str(round(slope,2)) + "x = " + str(round(intercept, 2))

plt.annotate(templine_eq,(6,10), fontsize=15, color="red")
plt.plot(income, tempregress_values, "r-")
plt.show()

print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: -0.15339048230981595

# %%
income = merged_table["Household Income"]
cancer_death = merged_table["Death Rate"]

plt.scatter(income,incidence_rate, edgecolors= "black", facecolors="green", alpha=.5)
plt.xlabel("Household Income (2018 inflated dollars)")
plt.ylabel("Death Rate")
plt.title("Household Income vs Cancer Death Rate")

(slope, intercept, rvalue, pvalue, stderr) = linregress(income, cancer_death)
tempregress_values = income*slope + intercept
templine_eq = "y = " + str(round(slope,2)) + "x = " + str(round(intercept, 2))

plt.annotate(templine_eq,(6,10), fontsize=15, color="red")
plt.plot(income, tempregress_values, "r-")
plt.show()

print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: -0.5426915623986303

# %%
income = merged_table["Household Income"]
Death_per_hundred = merged_table["Cancer Death_per_hundred_cancer_patient"]

plt.scatter(income,incidence_rate, edgecolors= "black", facecolors="orange", alpha=.5)
plt.xlabel("Household Income (2018 inflated dollars)")
plt.ylabel("Cancer Death per 100 People")
plt.title("Household Income vs Cancer Death per 100 People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(income, Death_per_hundred)
tempregress_values = income*slope + intercept
templine_eq = "y = " + str(round(slope,2)) + "x = " + str(round(intercept, 2))

plt.annotate(templine_eq,(6,10), fontsize=15, color="red")
plt.plot(income, tempregress_values, "r-")
plt.show()
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: -0.6620649247646108
