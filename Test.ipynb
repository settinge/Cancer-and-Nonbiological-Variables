# %%
# Dependencies
import json
import requests
import pandas as pd
from config import api_key
from config import census_api_key

# %%
url = f"https://api.census.gov/data/timeseries/asm/state?get=NAICS_TTL,EMP,GEO_TTL&for=state:*&YEAR=2016&NAICS=32*&key={census_api_key}"
response = requests.get(url)

# %%
manuf_info = response.json()

# %%
manufacturing_df = pd.DataFrame(manuf_info)
manufacturing_df
# Out:
#                                                     0      1             2  \
# 0                                           NAICS_TTL    EMP       GEO_TTL
# 1                          Wood product manufacturing  14054       Alabama
# 2                          Wood product manufacturing    343        Alaska
# 3                      Sawmills and wood preservation   5019       Alabama
# 4                      Sawmills and wood preservation     48        Alaska
# ...                                               ...    ...           ...
# 1361  Other nonmetallic mineral product manufacturing      0  North Dakota
# 1362  Other nonmetallic mineral product manufacturing    433      Oklahoma
# 1363  Other nonmetallic mineral product manufacturing   2864  Pennsylvania
# 1364  Other nonmetallic mineral product manufacturing    223  Rhode Island
# 1365  Other nonmetallic mineral product manufacturing   2393      Virginia
#
#          3      4      5
# 0     YEAR  NAICS  state
# 1     2016    321     01
# 2     2016    321     02
# 3     2016   3211     01
# 4     2016   3211     02
# ...    ...    ...    ...
# 1361  2016   3279     38
# 1362  2016   3279     40
# 1363  2016   3279     42
# 1364  2016   3279     44
# 1365  2016   3279     51
#
# [1366 rows x 6 columns]

# %%
del manufacturing_df[5]

# %%
manufacturing_df
# Out:
#                                                     0      1             2  \
# 0                                           NAICS_TTL    EMP       GEO_TTL
# 1                          Wood product manufacturing  14054       Alabama
# 2                          Wood product manufacturing    343        Alaska
# 3                      Sawmills and wood preservation   5019       Alabama
# 4                      Sawmills and wood preservation     48        Alaska
# ...                                               ...    ...           ...
# 1361  Other nonmetallic mineral product manufacturing      0  North Dakota
# 1362  Other nonmetallic mineral product manufacturing    433      Oklahoma
# 1363  Other nonmetallic mineral product manufacturing   2864  Pennsylvania
# 1364  Other nonmetallic mineral product manufacturing    223  Rhode Island
# 1365  Other nonmetallic mineral product manufacturing   2393      Virginia
#
#          3      4
# 0     YEAR  NAICS
# 1     2016    321
# 2     2016    321
# 3     2016   3211
# 4     2016   3211
# ...    ...    ...
# 1361  2016   3279
# 1362  2016   3279
# 1363  2016   3279
# 1364  2016   3279
# 1365  2016   3279
#
# [1366 rows x 5 columns]

# %%
manufact_edited = manufacturing_df.rename(columns={0:"Job Category",
                                                  1:"People Employed",
                                                  2:"State",
                                                  3:"Year",
                                                  4:"NAICS Code"})
manufact_edited.head()
# Out:
#                      Job Category People Employed    State  Year NAICS Code
# 0                       NAICS_TTL             EMP  GEO_TTL  YEAR      NAICS
# 1      Wood product manufacturing           14054  Alabama  2016        321
# 2      Wood product manufacturing             343   Alaska  2016        321
# 3  Sawmills and wood preservation            5019  Alabama  2016       3211
# 4  Sawmills and wood preservation              48   Alaska  2016       3211

# %%
# Mounir added .reset_index(drop=True) to reset the index. This doesn't happen automatically and when you do things like groupby it can keep adding to it. Screwing it up.
manufact_edited = manufact_edited.drop(0).reset_index(drop=True)
manufact_edited.head()
# Out:
#                                         Job Category People Employed    State  \
# 0                         Wood product manufacturing           14054  Alabama
# 1                         Wood product manufacturing             343   Alaska
# 2                     Sawmills and wood preservation            5019  Alabama
# 3                     Sawmills and wood preservation              48   Alaska
# 4  Veneer, plywood, and engineered wood product m...             182   Alaska
#
#    Year NAICS Code
# 0  2016        321
# 1  2016        321
# 2  2016       3211
# 3  2016       3211
# 4  2016       3212

# %%
manufact_edited.count()
# Out:
# Job Category       1365
# People Employed    1365
# State              1365
# Year               1365
# NAICS Code         1365
# dtype: int64

# %%
manufac_by_state = manufact_edited.sort_values(by="State").reset_index(drop=True)
manufac_by_state.head(25)
# Out:
#                                          Job Category People Employed  \
# 0                          Wood product manufacturing           14054
# 1   Resin, synthetic rubber, and artificial synthe...            4527
# 2     Other nonmetallic mineral product manufacturing             588
# 3                                 Paper manufacturing            9952
# 4                    Other wood product manufacturing            6960
# 5   Veneer, plywood, and engineered wood product m...            2075
# 6           Petroleum and coal products manufacturing            1733
# 7   Pesticide, fertilizer, and other agricultural ...             782
# 8           Nonmetallic mineral product manufacturing            5705
# 9                        Basic chemical manufacturing            3475
# 10              Glass and glass product manufacturing             992
# 11          Petroleum and coal products manufacturing            1733
# 12                             Chemical manufacturing           11901
# 13          Cement and concrete product manufacturing            2396
# 14              Lime and gypsum product manufacturing             468
# 15          Clay product and refractory manufacturing            1261
# 16          Pharmaceutical and medicine manufacturing            1132
# 17                       Rubber product manufacturing            4987
# 18            Printing and related support activities            3279
# 19         Paint, coating, and adhesive manufacturing            1035
# 20                     Plastics product manufacturing           12546
# 21                     Sawmills and wood preservation            5019
# 22  Soap, cleaning compound, and toilet preparatio...             233
# 23         Plastics and rubber products manufacturing           17534
# 24              Converted paper product manufacturing            2746
#
#       State  Year NAICS Code
# 0   Alabama  2016        321
# 1   Alabama  2016       3252
# 2   Alabama  2016       3279
# 3   Alabama  2016        322
# 4   Alabama  2016       3219
# 5   Alabama  2016       3212
# 6   Alabama  2016        324
# 7   Alabama  2016       3253
# 8   Alabama  2016        327
# 9   Alabama  2016       3251
# 10  Alabama  2016       3272
# 11  Alabama  2016       3241
# 12  Alabama  2016        325
# 13  Alabama  2016       3273
# 14  Alabama  2016       3274
# 15  Alabama  2016       3271
# 16  Alabama  2016       3254
# 17  Alabama  2016       3262
# 18  Alabama  2016        323
# 19  Alabama  2016       3255
# 20  Alabama  2016       3261
# 21  Alabama  2016       3211
# 22  Alabama  2016       3256
# 23  Alabama  2016        326
# 24  Alabama  2016       3222

# %%
manufac_by_state.sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-1244867c9c48> in <module>
# ----> 1 manufac_by_state.sum("People Employed")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11583             skipna=skipna,
#   11584             numeric_only=numeric_only,
# > 11585             min_count=min_count,
#   11586         )
#   11587
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7886         else:
#    7887             # TODO: Make other agg func handle axis=None properly
# -> 7888             axis = self._get_axis_number(axis)
#    7889             labels = self._get_agg_axis(axis)
#    7890             constructor = self._constructor
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     409             except KeyError:
#     410                 pass
# --> 411         raise ValueError("No axis named {0} for object type {1}".format(axis, cls))
#     412
#     413     @classmethod
#
# ValueError: No axis named People Employed for object type <class 'pandas.core.frame.DataFrame'>

# %%
list(set(manufac_by_state['Job Category']))
# Out:
# ['Pulp, paper, and paperboard mills',
#  'Sawmills and wood preservation',
#  'Nonmetallic mineral product manufacturing',
#  'Printing and related support activities',
#  'Plastics and rubber products manufacturing',
#  'Resin, synthetic rubber, and artificial synthetic fibers and filaments manufacturing',
#  'Soap, cleaning compound, and toilet preparation manufacturing',
#  'Lime and gypsum product manufacturing',
#  'Wood product manufacturing',
#  'Other nonmetallic mineral product manufacturing',
#  'Other chemical product and preparation manufacturing',
#  'Basic chemical manufacturing',
#  'Petroleum and coal products manufacturing',
#  'Veneer, plywood, and engineered wood product manufacturing',
#  'Other wood product manufacturing',
#  'Paper manufacturing',
#  'Glass and glass product manufacturing',
#  'Pharmaceutical and medicine manufacturing',
#  'Chemical manufacturing',
#  'Plastics product manufacturing',
#  'Paint, coating, and adhesive manufacturing',
#  'Rubber product manufacturing',
#  'Clay product and refractory manufacturing',
#  'Pesticide, fertilizer, and other agricultural chemical manufacturing',
#  'Cement and concrete product manufacturing',
#  'Converted paper product manufacturing']

# %%
manufac_by_industry = manufact_edited.sort_values(by="Job Category").reset_index(drop=True)
manufac_by_industry.head()
# Out:
#                    Job Category People Employed       State  Year NAICS Code
# 0  Basic chemical manufacturing            4474  New Jersey  2016       3251
# 1  Basic chemical manufacturing            7003        Ohio  2016       3251
# 2  Basic chemical manufacturing            4631    New York  2016       3251
# 3  Basic chemical manufacturing             820  New Mexico  2016       3251
# 4  Basic chemical manufacturing            2363    Missouri  2016       3251

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-4f6b4505eef7> in <module>
# ----> 1 Job_Cat_Sum.sum("Basic chemical manufacturing")
#
# TypeError: f() takes 1 positional argument but 2 were given

# %%
#Exporting 
manufac_by_state.to_csv("CSV Files/Manufacturing Jobs by State", index=False, header=True)
