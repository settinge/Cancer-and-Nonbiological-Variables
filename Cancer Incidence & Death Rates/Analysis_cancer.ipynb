# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np


# Study data files
Incidence_metadata = "Resource/New Cancer/incd (4).csv"
#Incidence_metadata="Users/Rupesh/Downloads/incd (4).csv"

Incidence_metadata = pd.read_csv(Incidence_metadata,skiprows=8)
Incidence_dropped = Incidence_metadata.dropna()
#Incidence_dropped[Incidence_dropped.Average Annual Count!=∂] 
Incidence_dropped = Incidence_dropped.loc[Incidence_dropped["Recent Trend"] != '∂']

# %%
Incidence_dropped_clean=Incidence_dropped.loc[Incidence_dropped["Recent Trend"] != '*']

Incidence_dropped_clean
# Out:
#                                      State     FIPS  \
# 0                     US (SEER+NPCR)(1,10)      0.0
# 1              Union County, Florida(6,10)  12125.0
# 2             Logan County, Nebraska(6,10)  31113.0
# 3             Powell County, Kentucky(7,8)  21197.0
# 4             Taylor County, Kentucky(7,8)  21217.0
# ...                                    ...      ...
# 2929                Rich County, Utah(7,8)  49033.0
# 2930           Eureka County, Nevada(6,10)  32011.0
# 2931         Culberson County, Texas(6,10)  48109.0
# 2933          Presidio County, Texas(6,10)  48377.0
# 2934  Aleutians East Borough, Alaska(6,10)   2013.0
#
#      Met Healthy People Objective of ***?  \
# 0                                     ***
# 1                                     ***
# 2                                     ***
# 3                                     ***
# 4                                     ***
# ...                                   ...
# ...

# %%
Incidence_dropped_reduced= Incidence_dropped_clean.drop([" FIPS","Met Healthy People Objective of ***?"], axis=1)
Incidence_dropped_reduced.drop(0)
# Out:
#                                      State  \
# 1              Union County, Florida(6,10)
# 2             Logan County, Nebraska(6,10)
# 3             Powell County, Kentucky(7,8)
# 4             Taylor County, Kentucky(7,8)
# 5          Robertson County, Kentucky(7,8)
# ...                                    ...
# 2929                Rich County, Utah(7,8)
# 2930           Eureka County, Nevada(6,10)
# 2931         Culberson County, Texas(6,10)
# 2933          Presidio County, Texas(6,10)
# 2934  Aleutians East Borough, Alaska(6,10)
#
#      Age-Adjusted Incidence Rate(Ü) - cases per 100,000  \
# 1                                                  1135
# 2                                                 677.2
# 3                                                 646.2
# 4                                                 623.3
# 5                                                 611.6
# ...                                                 ...
# ...

# %%
Incidence_dropped_reduced[['County','State']] = Incidence_dropped_reduced.State.apply(lambda x: pd.Series(str(x).split(",")))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-66a4fae12188> in <module>
# ----> 1 Incidence_dropped_reduced[['County','State']] = Incidence_dropped_reduced.State.apply(lambda x: pd.Series(str(x).split(",")))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3467             self._setitem_frame(key, value)
#    3468         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3469             self._setitem_array(key, value)
#    3470         else:
#    3471             # set column
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3490             if isinstance(value, DataFrame):
#    3491                 if len(value.columns) != len(key):
# -> 3492                     raise ValueError("Columns must be same length as key")
# ...
