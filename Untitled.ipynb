# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
from scipy.optimize import curve_fit
import numpy as np

# %%
data = pd.read_csv("Resource/heighest_lowest_Incidencerate_data.csv", delimiter=",",
                  ) 
data.head()
# Out:
#   State,Death Rate,Average Annual Count_y,Cancer Death_per_hundred_cancer_patient\tIncidence Rate\tAverage Annual Count_x
# 0      New Mexico,374.0,9116.0,144.0,3514.0,39.0\t\t
# 1       Arizona,387.0,30448.0,144.0,11508.0,38.0\t\t
# 2         Nevada,393.0,12409.0,162.0,4934.0,40.0\t\t
# 3          Wyoming,397.0,2638.0,145.0,943.0,36.0\t\t
# 4       Colorado,401.0,22701.0,139.0,7520.0,33.0\t\t

# %%
data["State"] = data["State,Death Rate,Average Annual Count_y,Cancer Death_per_hundred_cancer_patient\tIncidence Rate\tAverage Annual Count_x"].str.split(",",expand=True)[0]
data["Death Rate"]= data["State,Death Rate,Average Annual Count_y,Cancer Death_per_hundred_cancer_patient\tIncidence Rate\tAverage Annual Count_x"].str.split(",",expand=True)[1]
data["Average Annual Count"]= data["State,Death Rate,Average Annual Count_y,Cancer Death_per_hundred_cancer_patient\tIncidence Rate\tAverage Annual Count_x"].str.split(",",expand=True)[1]
data["Cancer Death per 100"]=""
data["Incidence Rate"]=""
data["Average Annual Count"]=""
data
# Out:
#    State,Death Rate,Average Annual Count_y,Cancer Death_per_hundred_cancer_patient\tIncidence Rate\tAverage Annual Count_x  \
# 0       New Mexico,374.0,9116.0,144.0,3514.0,39.0\t\t
# 1        Arizona,387.0,30448.0,144.0,11508.0,38.0\t\t
# 2          Nevada,393.0,12409.0,162.0,4934.0,40.0\t\t
# 3           Wyoming,397.0,2638.0,145.0,943.0,36.0\t\t
# 4        Colorado,401.0,22701.0,139.0,7520.0,33.0\t\t
# 5            Utah,403.0,10143.0,127.0,3021.0,30.0\t\t
# 6    California,405.0,165242.0,145.0,58588.0,35.0\t\t
# 7         Texas,408.0,107094.0,154.0,38943.0,36.0\t\t
# 8            Alaska,413.0,2784.0,165.0,977.0,35.0\t\t
# 9       Virginia,419.0,39078.0,161.0,14686.0,38.0\t\t
# 10           Maine,476.0,8700.0,174.0,3267.0,38.0\t\t
# 11  West Virginia,476.0,11653.0,189.0,4756.0,41.0\t\t
# 12    Rhode Island,478.0,6163.0,165.0,2223.0,36.0\t\t
# 13      Louisiana,481.0,24888.0,183.0,9346.0,38.0\t\t
# 14     New York,483.0,111527.0,151.0,35491.0,32.0\t\t
# ...

# %%
data[['State', 'Death Rate']] = data['State,Death Rate,Average Annual Count_y,Cancer Death_per_hundred_cancer_patient\tIncidence Rate\tAverage Annual Count_x'].str.split(',', expand=True)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-027d6ef8c61f> in <module>
# ----> 1 data[['State', 'Death Rate']] = data['State,Death Rate,Average Annual Count_y,Cancer Death_per_hundred_cancer_patient\tIncidence Rate\tAverage Annual Count_x'].str.split(',', expand=True)
#       2 data
#
# ~\New_Anaconda\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3467             self._setitem_frame(key, value)
#    3468         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3469             self._setitem_array(key, value)
#    3470         else:
#    3471             # set column
#
# ~\New_Anaconda\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3490             if isinstance(value, DataFrame):
#    3491                 if len(value.columns) != len(key):
# ...
