# %%
# Dependencies
import json
import requests
import pandas as pd
from config import api_key

# %%
url = f"https://api.census.gov/data/2017/cbp?get=NAICS2017_LABEL,NAICS2017,GEO_ID,LFO,LFO_LABEL,EMPSZES_LABEL,EMPSZES,EMP&for=state:01&key={api_key}"

response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
industry_json = response.json()

# %%
industry_json
# Out:
# [['NAICS2017_LABEL',
#   'NAICS2017',
#   'GEO_ID',
#   'LFO',
#   'LFO_LABEL',
#   'EMPSZES_LABEL',
#   'EMPSZES',
#   'EMP',
#   'state'],
#  ['Total for all sectors',
#   '00',
#   '0400000US01',
#   '933',
#   'Government',
#   'Establishments with 10 to 19 employees',
#   '230',
#   '62',
#   '01'],
#  ['Commercial and institutional building construction',
#   '23622',
#   '0400000US01',
#   '930',
#   'Partnerships',
#   'All establishments',
#   '001',
#   '3537',
#   '01'],
#  ['Commercial and institutional building construction',
#   '23622',
#   '0400000US01',
#   '930',
#   'Partnerships',
#   'Establishments with less than 5 employees',
#   '210',
#   '62',
#   '01'],
#  ['Commercial and institutional building construction',
#   '23622',
#   '0400000US01',
#   '930',
#   'Partnerships',
#   'Establishments with 5 to 9 employees',
#   '220',
#   '73',
#   '01'],
#  ['Commercial and institutional building construction',
#   '23622',
#   '0400000US01',
#   '930',
# ...

# %%
print(industry_json)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
